# %%
 # Llama-index psql vector store installs
# !pip install --upgrade pip
# %pip install llama-index llama-index-vector-stores-postgres llama-cpp-python
# Installing the BM25 retriever
# %pip install llama-index-retrievers-bm25
# Python connection to postgres
# %pip install psycopg2
# Helpe modules
# %pip install python-dotenv ipython-async
# Generating embeddings with SBERT 
# %pip install langchain langchain-community sentence-transformers
# %pip install llama-index-embeddings-langchain
# For a subsequent investigation into the generated embedding space
# %pip install matplotlib seaborn scikit-learn
# postgres stuff
# %pip install pgvector
# %pip install psycopg2-binary
# Out:
# Requirement already satisfied: pip in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (25.1.1)
# Collecting llama-index
#   Using cached llama_index-0.12.35-py3-none-any.whl.metadata (12 kB)
# Collecting llama-index-vector-stores-postgres
#   Using cached llama_index_vector_stores_postgres-0.5.3-py3-none-any.whl.metadata (555 bytes)
# Collecting llama-cpp-python
#   Using cached llama_cpp_python-0.3.9.tar.gz (67.9 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting llama-index-agent-openai<0.5,>=0.4.0 (from llama-index)
#   Using cached llama_index_agent_openai-0.4.7-py3-none-any.whl.metadata (438 bytes)
# Collecting llama-index-cli<0.5,>=0.4.1 (from llama-index)
#   Using cached llama_index_cli-0.4.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: llama-index-core<0.13,>=0.12.35 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index) (0.12.35)
# Collecting llama-index-embeddings-openai<0.4,>=0.3.0 (from llama-index)
#   Using cached llama_index_embeddings_openai-0.3.1-py3-none-any.whl.metadata (684 bytes)
# Collecting llama-index-indices-managed-llama-cloud>=0.4.0 (from llama-index)
#   Using cached llama_index_indices_managed_llama_cloud-0.6.11-py3-none-any.whl.metadata (3.6 kB)
# Collecting llama-index-llms-openai<0.4,>=0.3.0 (from llama-index)
#   Using cached llama_index_llms_openai-0.3.38-py3-none-any.whl.metadata (3.3 kB)
# Collecting llama-index-multi-modal-llms-openai<0.5,>=0.4.0 (from llama-index)
#   Using cached llama_index_multi_modal_llms_openai-0.4.3-py3-none-any.whl.metadata (726 bytes)
# Collecting llama-index-program-openai<0.4,>=0.3.0 (from llama-index)
#   Using cached llama_index_program_openai-0.3.1-py3-none-any.whl.metadata (764 bytes)
# Collecting llama-index-question-gen-openai<0.4,>=0.3.0 (from llama-index)
#   Using cached llama_index_question_gen_openai-0.3.0-py3-none-any.whl.metadata (783 bytes)
# Collecting llama-index-readers-file<0.5,>=0.4.0 (from llama-index)
#   Using cached llama_index_readers_file-0.4.7-py3-none-any.whl.metadata (5.4 kB)
# Collecting llama-index-readers-llama-parse>=0.4.0 (from llama-index)
#   Using cached llama_index_readers_llama_parse-0.4.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: nltk>3.8.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index) (3.9.1)
# Collecting openai>=1.14.0 (from llama-index-agent-openai<0.5,>=0.4.0->llama-index)
#   Using cached openai-1.78.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (3.11.18)
# Requirement already satisfied: aiosqlite in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (0.21.0)
# Requirement already satisfied: banks<3,>=2.0.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (2.1.2)
# Requirement already satisfied: dataclasses-json in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (2025.3.2)
# Requirement already satisfied: httpx in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (0.28.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (3.4.2)
# Requirement already satisfied: numpy in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (2.2.5)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (11.2.1)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (2.11.4)
# Requirement already satisfied: pyyaml>=6.0.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (2.32.3)
# Requirement already satisfied: sqlalchemy>=1.4.49 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.35->llama-index) (2.0.40)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (4.13.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13,>=0.12.35->llama-index) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.35->llama-index) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.35->llama-index) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.35->llama-index) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.35->llama-index) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.35->llama-index) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.35->llama-index) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.35->llama-index) (1.20.0)
# Requirement already satisfied: griffe in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.35->llama-index) (1.7.3)
# Requirement already satisfied: jinja2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.35->llama-index) (3.1.6)
# Requirement already satisfied: platformdirs in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.35->llama-index) (4.3.8)
# Collecting beautifulsoup4<5.0.0,>=4.12.3 (from llama-index-readers-file<0.5,>=0.4.0->llama-index)
#   Using cached beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting pandas (from llama-index-readers-file<0.5,>=0.4.0->llama-index)
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting pypdf<6.0.0,>=5.1.0 (from llama-index-readers-file<0.5,>=0.4.0->llama-index)
#   Using cached pypdf-5.4.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.5,>=0.4.0->llama-index)
#   Using cached striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5,>=0.4.0->llama-index)
#   Using cached soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (4.9.0)
# Collecting distro<2,>=1.7.0 (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.4.0 (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index)
#   Using cached jiter-0.9.0-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (3.10)
# Requirement already satisfied: certifi in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from httpx->llama-index-core<0.13,>=0.12.35->llama-index) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from httpx->llama-index-core<0.13,>=0.12.35->llama-index) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.13,>=0.12.35->llama-index) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.35->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.35->llama-index) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.35->llama-index) (0.4.0)
# Requirement already satisfied: colorama in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from tqdm<5,>=4.66.1->llama-index-core<0.13,>=0.12.35->llama-index) (0.4.6)
# Collecting asyncpg<1.0.0,>=0.29.0 (from llama-index-vector-stores-postgres)
#   Using cached asyncpg-0.30.0-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: pgvector<1.0.0,>=0.3.6 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-vector-stores-postgres) (0.4.1)
# Requirement already satisfied: psycopg2-binary<3.0.0,>=2.9.9 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-vector-stores-postgres) (2.9.10)
# Requirement already satisfied: greenlet>=1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.35->llama-index) (3.2.2)
# Collecting diskcache>=5.6.1 (from llama-cpp-python)
#   Using cached diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from jinja2->banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.35->llama-index) (3.0.2)
# Collecting llama-cloud<0.2.0,>=0.1.13 (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index)
#   Using cached llama_cloud-0.1.21-py3-none-any.whl.metadata (1.2 kB)
# Collecting llama-parse>=0.5.0 (from llama-index-readers-llama-parse>=0.4.0->llama-index)
#   Using cached llama_parse-0.6.22-py3-none-any.whl.metadata (6.9 kB)
# Collecting llama-cloud-services>=0.6.22 (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index)
#   Using cached llama_cloud_services-0.6.22-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-cloud-services>=0.6.22->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (8.2.0)
# Collecting llama-cloud<0.2.0,>=0.1.13 (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index)
#   Using cached llama_cloud-0.1.19-py3-none-any.whl.metadata (902 bytes)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-cloud-services>=0.6.22->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (1.1.0)
# Requirement already satisfied: joblib in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from nltk>3.8.1->llama-index) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from nltk>3.8.1->llama-index) (2024.11.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13,>=0.12.35->llama-index) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13,>=0.12.35->llama-index) (2.4.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13,>=0.12.35->llama-index) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from dataclasses-json->llama-index-core<0.13,>=0.12.35->llama-index) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13,>=0.12.35->llama-index) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index) (1.17.0)
# Using cached llama_index-0.12.35-py3-none-any.whl (7.0 kB)
# Using cached llama_index_agent_openai-0.4.7-py3-none-any.whl (14 kB)
# Using cached llama_index_cli-0.4.1-py3-none-any.whl (28 kB)
# Using cached llama_index_embeddings_openai-0.3.1-py3-none-any.whl (6.2 kB)
# Using cached llama_index_llms_openai-0.3.38-py3-none-any.whl (23 kB)
# Using cached llama_index_multi_modal_llms_openai-0.4.3-py3-none-any.whl (5.9 kB)
# Using cached llama_index_program_openai-0.3.1-py3-none-any.whl (5.3 kB)
# Using cached llama_index_question_gen_openai-0.3.0-py3-none-any.whl (2.9 kB)
# Using cached llama_index_readers_file-0.4.7-py3-none-any.whl (40 kB)
# Using cached beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Using cached openai-1.78.0-py3-none-any.whl (680 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached jiter-0.9.0-cp312-cp312-win_amd64.whl (207 kB)
# Using cached pypdf-5.4.0-py3-none-any.whl (302 kB)
# Using cached striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Using cached llama_index_vector_stores_postgres-0.5.3-py3-none-any.whl (10 kB)
# Using cached asyncpg-0.30.0-cp312-cp312-win_amd64.whl (621 kB)
# Using cached diskcache-5.6.3-py3-none-any.whl (45 kB)
# Using cached llama_index_indices_managed_llama_cloud-0.6.11-py3-none-any.whl (14 kB)
# Using cached llama_index_readers_llama_parse-0.4.0-py3-none-any.whl (2.5 kB)
# Using cached llama_parse-0.6.22-py3-none-any.whl (4.9 kB)
# Using cached llama_cloud_services-0.6.22-py3-none-any.whl (37 kB)
# Using cached llama_cloud-0.1.19-py3-none-any.whl (263 kB)
# Using cached soupsieve-2.7-py3-none-any.whl (36 kB)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Building wheels for collected packages: llama-cpp-python
#   Building wheel for llama-cpp-python (pyproject.toml): started
#   Building wheel for llama-cpp-python (pyproject.toml): still running...
#   Building wheel for llama-cpp-python (pyproject.toml): still running...
#   Building wheel for llama-cpp-python (pyproject.toml): finished with status 'done'
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.3.9-cp312-cp312-win_amd64.whl size=3378901 sha256=89e971d11aecc0aba503e16deec616ad490e5f45fa3d21f0a9026e46a5bb255e
#   Stored in directory: c:\users\acisse\appdata\local\pip\cache\wheels\e9\22\42\98dca29f6195951fae2aa548582827a45306350e282ab30617
# Successfully built llama-cpp-python
# Installing collected packages: striprtf, pytz, tzdata, soupsieve, pypdf, jiter, distro, diskcache, asyncpg, pandas, llama-cpp-python, beautifulsoup4, openai, llama-cloud, llama-index-vector-stores-postgres, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-cloud-services, llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-readers-llama-parse, llama-index-program-openai, llama-index-question-gen-openai, llama-index
#
#    - --------------------------------------  1/28 [pytz]
#    - --------------------------------------  1/28 [pytz]
#    - --------------------------------------  1/28 [pytz]
#    -- -------------------------------------  2/28 [tzdata]
#    -- -------------------------------------  2/28 [tzdata]
#    -- -------------------------------------  2/28 [tzdata]
#    ---- -----------------------------------  3/28 [soupsieve]
#    ----- ----------------------------------  4/28 [pypdf]
#    ----- ----------------------------------  4/28 [pypdf]
#    ----- ----------------------------------  4/28 [pypdf]
#    ----- ----------------------------------  4/28 [pypdf]
#    ----- ----------------------------------  4/28 [pypdf]
#    ----- ----------------------------------  4/28 [pypdf]
#    ----- ----------------------------------  4/28 [pypdf]
#    ----- ----------------------------------  4/28 [pypdf]
#    ----- ----------------------------------  4/28 [pypdf]
#    ----- ----------------------------------  4/28 [pypdf]
#    ----- ----------------------------------  4/28 [pypdf]
#    -------- -------------------------------  6/28 [distro]
#    -------- -------------------------------  6/28 [distro]
#    ---------- -----------------------------  7/28 [diskcache]
#    ----------- ----------------------------  8/28 [asyncpg]
#    ----------- ----------------------------  8/28 [asyncpg]
#    ----------- ----------------------------  8/28 [asyncpg]
#    ----------- ----------------------------  8/28 [asyncpg]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    ------------ ---------------------------  9/28 [pandas]
#    -------------- ------------------------- 10/28 [llama-cpp-python]
#    -------------- ------------------------- 10/28 [llama-cpp-python]
#    -------------- ------------------------- 10/28 [llama-cpp-python]
#    -------------- ------------------------- 10/28 [llama-cpp-python]
#    --------------- ------------------------ 11/28 [beautifulsoup4]
#    --------------- ------------------------ 11/28 [beautifulsoup4]
#    --------------- ------------------------ 11/28 [beautifulsoup4]
#    --------------- ------------------------ 11/28 [beautifulsoup4]
#    --------------- ------------------------ 11/28 [beautifulsoup4]
#    --------------- ------------------------ 11/28 [beautifulsoup4]
#    --------------- ------------------------ 11/28 [beautifulsoup4]
#    --------------- ------------------------ 11/28 [beautifulsoup4]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ----------------- ---------------------- 12/28 [openai]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ------------------ --------------------- 13/28 [llama-cloud]
#    ---------------- ---------------- 14/28 [llama-index-vector-stores-postgres]
#    --------------------- ------------------ 15/28 [llama-index-readers-file]
#    --------------------- ------------------ 15/28 [llama-index-readers-file]
#    --------------------- ------------------ 15/28 [llama-index-readers-file]
#    --------------------- ------------------ 15/28 [llama-index-readers-file]
#    --------------------- ------------------ 15/28 [llama-index-readers-file]
#    ---------------------- ----------------- 16/28 [llama-index-llms-openai]
#    ----------------- ---------- 17/28 [llama-index-indices-managed-llama-cloud]
#    ------------------------ ------------- 18/28 [llama-index-embeddings-openai]
#    --------------------------- ------------ 19/28 [llama-cloud-services]
#    --------------------------- ------------ 19/28 [llama-cloud-services]
#    --------------------------- ------------ 19/28 [llama-cloud-services]
#    --------------------------- ------------ 19/28 [llama-cloud-services]
#    ---------------------------- ----------- 20/28 [llama-parse]
#    ---------------------------- ----------- 20/28 [llama-parse]
#    ------------------------------- -------- 22/28 [llama-index-cli]
#    ------------------------------- -------- 22/28 [llama-index-cli]
#    ------------------------------- -------- 22/28 [llama-index-cli]
#    -------------------------------- ------- 23/28 [llama-index-agent-openai]
#    ----------------------------------- ---- 25/28 [llama-index-program-openai]
#    -------------------------------------- - 27/28 [llama-index]
#    -------------------------------------- - 27/28 [llama-index]
#    ---------------------------------------- 28/28 [llama-index]
#
# Successfully installed asyncpg-0.30.0 beautifulsoup4-4.13.4 diskcache-5.6.3 distro-1.9.0 jiter-0.9.0 llama-cloud-0.1.19 llama-cloud-services-0.6.22 llama-cpp-python-0.3.9 llama-index-0.12.35 llama-index-agent-openai-0.4.7 llama-index-cli-0.4.1 llama-index-embeddings-openai-0.3.1 llama-index-indices-managed-llama-cloud-0.6.11 llama-index-llms-openai-0.3.38 llama-index-multi-modal-llms-openai-0.4.3 llama-index-program-openai-0.3.1 llama-index-question-gen-openai-0.3.0 llama-index-readers-file-0.4.7 llama-index-readers-llama-parse-0.4.0 llama-index-vector-stores-postgres-0.5.3 llama-parse-0.6.22 openai-1.78.0 pandas-2.2.3 pypdf-5.4.0 pytz-2025.2 soupsieve-2.7 striprtf-0.0.26 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index-retrievers-bm25 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (0.5.2)
# Requirement already satisfied: bm25s<0.3.0,>=0.2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-retrievers-bm25) (0.2.12)
# ...
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (2025.4.26)
# Requirement already satisfied: greenlet>=1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (3.2.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (24.2)
# Requirement already satisfied: anyio in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from jinja2->banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-langchain) (3.0.2)
# Using cached llama_index_embeddings_langchain-0.3.0-py3-none-any.whl (2.5 kB)
# Installing collected packages: llama-index-embeddings-langchain
# Successfully installed llama-index-embeddings-langchain-0.3.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting matplotlib
#   Downloading matplotlib-3.10.3-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: scikit-learn in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (1.6.1)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.58.0-cp312-cp312-win_amd64.whl.metadata (106 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from matplotlib) (2.2.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from matplotlib) (11.2.1)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.3-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.1 MB 5.0 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.1 MB 9.2 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.1 MB 9.3 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 8.9 MB/s eta 0:00:00
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading contourpy-1.3.2-cp312-cp312-win_amd64.whl (223 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.58.0-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 12.6 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ----------- ---------------------------- 2/7 [fonttools]
#    ---------------------- ----------------- 4/7 [contourpy]
#    ---------------------- ----------------- 4/7 [contourpy]
#    ---------------------- ----------------- 4/7 [contourpy]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------- ----------- 5/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [seaborn]
#    ---------------------------------- ----- 6/7 [seaborn]
#    ---------------------------------- ----- 6/7 [seaborn]
#    ---------------------------------- ----- 6/7 [seaborn]
#    ---------------------------------- ----- 6/7 [seaborn]
#    ---------------------------------- ----- 6/7 [seaborn]
#    ---------------------------------- ----- 6/7 [seaborn]
#    ---------------------------------- ----- 6/7 [seaborn]
#    ---------------------------------- ----- 6/7 [seaborn]
#    ---------------------------------------- 7/7 [seaborn]
#
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.58.0 kiwisolver-1.4.8 matplotlib-3.10.3 pyparsing-3.2.3 seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pgvector in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (0.4.1)
# Requirement already satisfied: numpy in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pgvector) (2.2.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: psycopg2-binary in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (2.9.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install docker
# %pip install -U langchain-huggingface
# Out:
# Requirement already satisfied: docker in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (7.1.0)
# Requirement already satisfied: pywin32>=304 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from docker) (310)
# Requirement already satisfied: requests>=2.26.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from docker) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from docker) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from requests>=2.26.0->docker) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from requests>=2.26.0->docker) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from requests>=2.26.0->docker) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain-huggingface
#   Downloading langchain_huggingface-0.2.0-py3-none-any.whl.metadata (941 bytes)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.59 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from langchain-huggingface) (0.3.59)
# Requirement already satisfied: tokenizers>=0.19.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from langchain-huggingface) (0.21.1)
# Requirement already satisfied: transformers>=4.39.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from langchain-huggingface) (4.51.3)
# Requirement already satisfied: sentence-transformers>=2.6.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from langchain-huggingface) (4.1.0)
# Requirement already satisfied: huggingface-hub>=0.30.2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from langchain-huggingface) (0.31.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.3.42)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (4.13.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (2.11.4)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.23.0)
# Requirement already satisfied: anyio in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (4.9.0)
# Requirement already satisfied: certifi in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (1.0.9)
# Requirement already satisfied: idna in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (2.4.0)
# Requirement already satisfied: filelock in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (2025.3.2)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from huggingface-hub>=0.30.2->langchain-huggingface) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (2.7.0)
# Requirement already satisfied: scikit-learn in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.6.1)
# Requirement already satisfied: scipy in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (1.15.3)
# Requirement already satisfied: Pillow in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from sentence-transformers>=2.6.0->langchain-huggingface) (11.2.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from transformers>=4.39.0->langchain-huggingface) (2.2.5)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from transformers>=4.39.0->langchain-huggingface) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from transformers>=4.39.0->langchain-huggingface) (0.5.3)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.14.0)
# Requirement already satisfied: networkx in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (80.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (1.3.0)
# Requirement already satisfied: colorama in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.30.2->langchain-huggingface) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.59->langchain-huggingface) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain-huggingface) (3.0.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain-huggingface) (3.6.0)
# Downloading langchain_huggingface-0.2.0-py3-none-any.whl (27 kB)
# Installing collected packages: langchain-huggingface
# Successfully installed langchain-huggingface-0.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext ipython_async

# %%
# !mkdir postgres-data

# %%
import docker
from docker.types import Mount
from docker.errors import NotFound, APIError

client = docker.from_env()
container_name = "pgvector-db"

try:
    # Try to get the existing container
    container = client.containers.get(container_name)
    if container.status != "running":
        print(f"Starting existing container: {container.name}")
        container.start()
    else:
        print(f"Container '{container.name}' is already running.")
except NotFound:
    print(f"Creating and starting new container: {container_name}")
    container = client.containers.run(
        image="ankane/pgvector:v0.5.1",
        name=container_name,
        detach=True,
        restart_policy={"Name": "unless-stopped"},
        environment={
            "POSTGRES_USER": "postgres",
            "POSTGRES_DB": "postgres",
            "POSTGRES_PASSWORD": "postgres"
        },
        mounts=[
            Mount(target="/var/lib/postgresql/data", source="postgres-data", type="volume")
        ],
        healthcheck={
            "test": ["CMD", "pg_isready", "-U", "postgres"],
            "interval": 5_000_000_000,  # nanoseconds
            "retries": 5,
        },
        ports={"5432/tcp": 5432}
    )

print(f"Container is running: {container.name}")
# Out:
# Creating and starting new container: pgvector-db
# Container is running: pgvector-db

# %%
# !netstat -ano | findstr :5432
# Out:
#   TCP    0.0.0.0:5432           0.0.0.0:0              LISTENING       38592
#   TCP    [::]:5432              [::]:0                 LISTENING       38592
#   TCP    [::1]:5432             [::]:0                 LISTENING       3872

# %%
import os
import psycopg2
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
db_name = "vector_db"
user = "postgres"
host = "db" if os.getenv("DEVCONTAINER") == "true" else "localhost"
host
# Out:
# 'localhost'

# %%
conn = psycopg2.connect(
    dbname="postgres",
    host=host,
    password="postgres",
    port=5432,
    user=user,
)
conn.set_client_encoding('UTF8')
conn.autocommit = True

with conn.cursor() as c:
    c.execute(f"DROP DATABASE IF EXISTS {db_name}")         # Create our vector db
    c.execute(f"CREATE DATABASE {db_name}")
    c.execute(f"CREATE EXTENSION IF NOT EXISTS vector")     # Install the extension

# %%
from llama_index.vector_stores.postgres import PGVectorStore

vector_store = PGVectorStore.from_params(
    database=db_name,
    host=host,
    password="postgres",
    port=5432,
    user=user,
    table_name="physics_docs",
    embed_dim=384,
    hybrid_search=True
)

# %%
from llama_index.embeddings.langchain import LangchainEmbedding
from langchain_huggingface import HuggingFaceEmbeddings

# Load MiniLM embedding model (fast & efficient)
embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Wrap the model for LlamaIndex
embed_model = LangchainEmbedding(embedding_model)

# %%
# !git clone https://github.com/amadou-6e/ai-data-zoo.git
# Out:
# Cloning into 'ai-data-zoo'...

# %%
# !tar -xzf ai-data-zoo/markdown.zip

# %%
from pathlib import Path
from llama_index.core import SimpleDirectoryReader

# Define the directory containing documents
source_dir = Path("markdown")

# Load markdown documents
documents = SimpleDirectoryReader(source_dir, required_exts=[".md"], recursive=True).load_data()
print(f"Loaded {len(documents)} documents")
# Out:
# Loaded 16 documents

# %%
from llama_index.core import StorageContext, VectorStoreIndex

storage_context = StorageContext.from_defaults(vector_store=vector_store)

# Index the documents and store embeddings
index = VectorStoreIndex.from_documents(
    documents, 
    storage_context=storage_context, 
    embed_model=embed_model, 
    show_progress=True,
)
# Out:
# Parsing nodes:   0%|          | 0/16 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/297 [00:00<?, ?it/s]

# %%
from IPython.display import display, Markdown

# %%
query = "Who developped / discovered the ADF-CFT correspondence?"
query = "Who is Richard Feynman?"

# %%
retriever = index.as_retriever(similarity_top_k=5)
results = retriever.retrieve(query)

for idx, node in enumerate(results):
    print(f"Result {idx+1}\n")
    print(f"Score: {node.score}")
    print(f"Start char idx: {node.dict()['node']['start_char_idx']}; End char idx: {node.dict()['node']['end_char_idx']}")
    print(f"Location: {Path(node.metadata['file_path']).parent.stem}")
    text_sample =  "\n".join(f"> {line}" for line in node.text[:600].split("\n"))
    display(Markdown(text_sample))
    print('-'*50)
# Out:
# Result 1
#
# Score: 0.6395445251193371
# Start char idx: 0; End char idx: 3147
# Location: de-feynman
# > # WIKIPEDIA
# >
# > # Richard Feynman
# >
# > Richard Phillips Feynman [ˈfammən] (\* 11. Mai 1918 in Queens, New York; + 15. Februar 1988 in Los Angeles) war ein US-amerikanischer Physiker und Nobelpreisträger des Jahres 1965.
# >
# > Feynman gilt als einer der großen Physiker des 20. Jahrhunderts, der wesentliche Beiträge zum Verständnis der Quantenfeldtheorien geliefert hat. Zusammen mit Shin'ichirō Tomonaga und Julian Schwinger erhielt er 1965 den Nobelpreis für seine Arbeit zur Quantenelektrodynamik (QED). Seine anschauliche Darstellung quantenfeldtheoretischer elementarer Wechselwirkungen durch Feynman-
# --------------------------------------------------
# Result 2
#
# Score: 0.5868013850928189
# Start char idx: 31884; End char idx: 33934
# Location: de-feynman
# > 1979 (berichtet über die Zusammenarbeit mit Feynman Ende der 1940er Jahre)
# > - Jörg Resag: Feynman und die Physik. Leben und Forschung eines außergewöhnlichen Menschen. Springer 2018, ISBN 978-3-662-54796-0.
# > - = Silvan S. Schweber: Quantum Electrodynamics and the men who made it. Princeton University Press, 1994
# > - = Leonard Mlodinow: Feynman's Rainbow. A Search for Beauty in Physics and in Life. 2003 (dt. Feynmans Regenbogen. Die Suche nach Schönheit in der Physik und im Leben. Reclam, 2005, ISBN 3-379-00826-5) – beschreibt autobiografisch die Zeit des Autors Anfang der 1980er Jahre am Caltec
# --------------------------------------------------
# Result 3
#
# Score: 0.5666405479144437
# Start char idx: 35673; End char idx: 38436
# Location: de-feynman
# > The dispersion of Feynman diagrams in post-war physics, University of Chicago Press 2005.
# > - 2. Richard Feynman: The 1979 The Sir Douglas Robb Lectures (http://www.vega.org.uk/video/su bseries/8) Teile 1-4, University of Auckland, Grundlage des populärwissenschaftlichen Buches: QED: Die seltsame Theorie des Lichts und der Materie.
# > - 3. Richard P. Feynman: Cargo Cult Science: Some remarks on science, pseudoscience, and learning how to not fool yourself. Caltech's 1974 commencement address. Ihttp://calteches.libr ary.caltech.edu/51/2/CargoCult.htm) In: caltech.edu. Abgerufen am 11. Mai 2018 (en
# --------------------------------------------------
# Result 4
#
# Score: 0.5212680852791098
# Start char idx: 33277; End char idx: 36287
# Location: de-feynman
# > Folge der 9. Staffel leihen sie sich Feynmans Van für einen Ausflug. In der 2. Folge der 11. Staffel treffen sie sich an Feynmans Grab, um ihn mit einer Runde romulanischem Ale (ein Getränk aus der fiktionalen Fernsehserie Raumschiff Enterprise) zu würdigen.
# > - Im Film Oppenheimer, welcher die Ereignisse rund um das Manhattan Project in Los Alamos zeigt, wird Feynman von dem Schauspieler Jack Quaid verkörpert
# >
# > # Videos
# >
# > ▪ The 1979 The Sir Douglas Robb Lectures (http://www.vega.org.uk/video/subseries/8) University of Auckland, vierteiliges Video, Grundlage des populärwissenschaftlichen Buch
# --------------------------------------------------
# Result 5
#
# Score: 0.5211869788877365
# Start char idx: 22323; End char idx: 25175
# Location: de-feynman
# > – RICHARD P. FEYNMAN[40]
# >
# > # Werke
# >
# > ### Bücher von Feynman über Physik
# >
# > - · mit Robert B. Leighton und Matthew Sands: The Feynman Lectures on Physics. 3 Bände, ISBN 0-201-02115-3 (dt. Feynman-Vorlesungen über Physik. 5. Bände, 6. Aufl. De Gruyter 2015), zuerst 1963/1965 bei Addison/Wesley (in Band 3 Quantenmechanik über Diracs Bra-Ket-Notation behandelt, als Anwendung Maser, Transistor, Josephson-Effekt), Die englische Originalausgabe ist online verfügbar (http://www.feynmanlectures.caltech.edu/)
# > - QED: The Strange Theory of Light and Matter 1985 (dt. QED: Die seltsame Theorie des Lichts
# --------------------------------------------------

# %%
from llama_index.core.vector_stores.types import VectorStoreQueryMode

retriever = index.as_retriever(similarity_top_k=3, vector_store_query_mode=VectorStoreQueryMode.SPARSE)
results = retriever.retrieve(query)

for idx, node in enumerate(results):
    print(f"Result {idx+1}\n")
    print(f"Score: {node.score}")
    print(f"Start char idx: {node.dict()['node']['start_char_idx']}; End char idx: {node.dict()['node']['end_char_idx']}")
    print(f"Location: {Path(node.metadata['file_path']).parent.stem}")
    text_sample =  "\n".join(f"> {line}" for line in node.text[:600].split("\n"))
    display(Markdown(text_sample))
    print('-'*50)
# Out:
# Result 1
#
# Score: 0.09625329
# Start char idx: 29321; End char idx: 32283
# Location: de-feynman
# > ISBN 3-492-22166-1) (u. a. über die Challenger-Katastrophe, sein Hobby Zeichnen, seine erste Frau Arlene, seinen Vater; mit dem Vortrag The value of science)
# >
# > ### Bücher von Feynman über anderes
# >
# > - The Art of Richard P. Feynman. Images by a Curious Character. ISBN 2-88449-047-7.
# > - The Meaning of it all (dt. Was soll das alles? Gedanken eines Physikers. ISBN 3-492-23316-3) (drei populäre Vorlesungen Anfang der 60er Jahre an University of Washington, u. a. value of science)
# > - The Pleasure of Finding Things out. The Best Short Works of Richard P. Feynman. Penguin 2001 (dt. Es ist so einfach
# --------------------------------------------------
# Result 2
#
# Score: 0.0946916
# Start char idx: 33277; End char idx: 36287
# Location: de-feynman
# > Folge der 9. Staffel leihen sie sich Feynmans Van für einen Ausflug. In der 2. Folge der 11. Staffel treffen sie sich an Feynmans Grab, um ihn mit einer Runde romulanischem Ale (ein Getränk aus der fiktionalen Fernsehserie Raumschiff Enterprise) zu würdigen.
# > - Im Film Oppenheimer, welcher die Ereignisse rund um das Manhattan Project in Los Alamos zeigt, wird Feynman von dem Schauspieler Jack Quaid verkörpert
# >
# > # Videos
# >
# > ▪ The 1979 The Sir Douglas Robb Lectures (http://www.vega.org.uk/video/subseries/8) University of Auckland, vierteiliges Video, Grundlage des populärwissenschaftlichen Buch
# --------------------------------------------------
# Result 3
#
# Score: 0.09284579
# Start char idx: 0; End char idx: 3147
# Location: de-feynman
# > # WIKIPEDIA
# >
# > # Richard Feynman
# >
# > Richard Phillips Feynman [ˈfammən] (\* 11. Mai 1918 in Queens, New York; + 15. Februar 1988 in Los Angeles) war ein US-amerikanischer Physiker und Nobelpreisträger des Jahres 1965.
# >
# > Feynman gilt als einer der großen Physiker des 20. Jahrhunderts, der wesentliche Beiträge zum Verständnis der Quantenfeldtheorien geliefert hat. Zusammen mit Shin'ichirō Tomonaga und Julian Schwinger erhielt er 1965 den Nobelpreis für seine Arbeit zur Quantenelektrodynamik (QED). Seine anschauliche Darstellung quantenfeldtheoretischer elementarer Wechselwirkungen durch Feynman-
# --------------------------------------------------

# %%
from llama_index.core.vector_stores.types import MetadataFilters

# Create a filter that matches everything
filters = MetadataFilters(filters=[])  # Empty dictionary

all_nodes = vector_store.get_nodes(filters=filters)
embeddings = [node.embedding for node in all_nodes]
len(embeddings[0])
# Out:
# 384

# %%
from llama_index.retrievers.bm25 import BM25Retriever
bm25_retriever = BM25Retriever.from_defaults(
    nodes=all_nodes,
    similarity_top_k=3,
)

# Query
query = "When did Witten get his Nobel Prize?"
hybrid_results = bm25_retriever.retrieve(query)

# Print results
for idx, node in enumerate(hybrid_results):
    print(f"Result {idx+1}\n")
    print(f"Score: {node.score}")
    print(f"Start char idx: {node.dict()['node']['start_char_idx']}; End char idx: {node.dict()['node']['end_char_idx']}")
    print(f"Location: {Path(node.metadata['file_path']).parent.stem}")
    text_sample = "\n".join(f"> {line}" for line in node.text[:600].split("\n"))
    display(Markdown(text_sample))
    print('-' * 50)
# Out:
# resource module not available on Windows
# Result 1
#
# Score: 6.016958713531494
# Start char idx: 0; End char idx: 4485
# Location: eng-feynman-the-development-of-the-qed-space-time-view
# > # THE DEVELOPMENT OF THE SPACE-TIME VIEW OF QUANTUM ELECTRODYNAMICS<sup>∗</sup>
# >
# > by
# >
# > ### Richard P. Feynman
# >
# > California Institute of Technology, Pasadena, California
# >
# > Nobel Lecture, December 11, 1965.
# >
# > We have a habit in writing articles published in scientific journals to make the work as finished as possible, to cover all the tracks, to not worry about the blind alleys or to describe how you had the wrong idea first, and so on. So there isn't any place to publish, in a dignified manner, what you actually did in order to get to do the work, although, there has been in these days, so
# --------------------------------------------------
# Result 2
#
# Score: 5.186384201049805
# Start char idx: 52707; End char idx: 57128
# Location: eng-feynman-the-development-of-the-qed-space-time-view
# > I didn't have the knowledge to understand the way these were defined in the conventional papers because they were expressed at that time in terms of creation and annihilation operators, and so on, which, I had not successfully learned. I remember that when someone had started to teach me about creation and annihilation operators, that this operator creates an electron, I said, "how do you create an electron? It disagrees with the conservation of charge," and in that way, I blocked my mind from learning a very practical scheme of calculation. Therefore, I had to find as many opportunities as po
# --------------------------------------------------
# Result 3
#
# Score: 4.586615562438965
# Start char idx: 0; End char idx: 5599
# Location: de-juan-maldacena
# > ![](_page_0_Picture_2.jpeg)
# >
# > # Juan Maldacena
# >
# > Juan Martín Maldacena (born 10 September 1968) is an Argentine theoretical physicist and the Carl P. Feinberg Professor in the School of Natural Sciences at the Institute for Advanced Study, Princeton. 3 He has made significant contributions to the foundations of string theory and quantum gravity. His most famous discovery is the AdS/CFT correspondence, a realization of the holographic principle in string theory.
# >
# > # Biography
# >
# > ![](_page_0_Picture_6.jpeg)
# >
# > Instituto Balseiro at which Maldacena obtained his Physics licenciatura
# >
# > Maldacen
# --------------------------------------------------

# %%
# %pip install llama-cpp-python
# %pip install openai
# %pip install llama-index-llms-llama-cpp
# %pip install llama-index-postprocessor-colbert-rerank
# Out:
# Requirement already satisfied: llama-cpp-python in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (0.3.9)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-cpp-python) (4.13.2)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-cpp-python) (2.2.5)
# Requirement already satisfied: diskcache>=5.6.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-cpp-python) (5.6.3)
# Requirement already satisfied: jinja2>=2.11.3 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-cpp-python) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from jinja2>=2.11.3->llama-cpp-python) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: openai in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (1.78.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from openai) (2.11.4)
# Requirement already satisfied: sniffio in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from openai) (4.13.2)
# Requirement already satisfied: idna>=2.8 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
# Requirement already satisfied: colorama in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Collecting llama-index-llms-llama-cpp
#   Using cached llama_index_llms_llama_cpp-0.4.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: llama-cpp-python<0.4.0,>=0.3.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-llms-llama-cpp) (0.3.9)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-llms-llama-cpp) (0.12.35)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-cpp-python<0.4.0,>=0.3.0->llama-index-llms-llama-cpp) (4.13.2)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-cpp-python<0.4.0,>=0.3.0->llama-index-llms-llama-cpp) (2.2.5)
# Requirement already satisfied: diskcache>=5.6.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-cpp-python<0.4.0,>=0.3.0->llama-index-llms-llama-cpp) (5.6.3)
# Requirement already satisfied: jinja2>=2.11.3 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-cpp-python<0.4.0,>=0.3.0->llama-index-llms-llama-cpp) (3.1.6)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (3.11.18)
# Requirement already satisfied: aiosqlite in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (0.21.0)
# Requirement already satisfied: banks<3,>=2.0.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (2.1.2)
# Requirement already satisfied: dataclasses-json in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (2025.3.2)
# Requirement already satisfied: httpx in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (0.28.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (3.9.1)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (11.2.1)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (2.11.4)
# Requirement already satisfied: pyyaml>=6.0.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (2.32.3)
# Requirement already satisfied: sqlalchemy>=1.4.49 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (2.0.40)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (4.67.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (1.20.0)
# Requirement already satisfied: griffe in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (1.7.3)
# Requirement already satisfied: platformdirs in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (4.3.8)
# Requirement already satisfied: colorama in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from tqdm<5,>=4.66.1->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (0.4.6)
# Requirement already satisfied: idna>=2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (3.10)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from jinja2>=2.11.3->llama-cpp-python<0.4.0,>=0.3.0->llama-index-llms-llama-cpp) (3.0.2)
# Requirement already satisfied: click in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (8.2.0)
# Requirement already satisfied: joblib in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (2025.4.26)
# Requirement already satisfied: greenlet>=1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (3.2.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (24.2)
# Requirement already satisfied: anyio in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-llama-cpp) (1.3.1)
# Using cached llama_index_llms_llama_cpp-0.4.0-py3-none-any.whl (7.5 kB)
# Installing collected packages: llama-index-llms-llama-cpp
# Successfully installed llama-index-llms-llama-cpp-0.4.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting llama-index-postprocessor-colbert-rerank
#   Using cached llama_index_postprocessor_colbert_rerank-0.3.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-postprocessor-colbert-rerank) (0.12.35)
# Requirement already satisfied: torch<3.0.0,>=2.2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-postprocessor-colbert-rerank) (2.7.0)
# Requirement already satisfied: transformers<5.0.0,>=4.37.2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-postprocessor-colbert-rerank) (4.51.3)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (3.11.18)
# Requirement already satisfied: aiosqlite in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (0.21.0)
# Requirement already satisfied: banks<3,>=2.0.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (2.1.2)
# Requirement already satisfied: dataclasses-json in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (2025.3.2)
# Requirement already satisfied: httpx in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (0.28.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (3.9.1)
# Requirement already satisfied: numpy in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (2.2.5)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (11.2.1)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (2.11.4)
# Requirement already satisfied: pyyaml>=6.0.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (2.32.3)
# Requirement already satisfied: sqlalchemy>=1.4.49 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (2.0.40)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (4.13.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (1.20.0)
# Requirement already satisfied: griffe in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (1.7.3)
# Requirement already satisfied: jinja2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (3.1.6)
# Requirement already satisfied: platformdirs in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (4.3.8)
# Requirement already satisfied: filelock in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from torch<3.0.0,>=2.2.0->llama-index-postprocessor-colbert-rerank) (3.18.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from torch<3.0.0,>=2.2.0->llama-index-postprocessor-colbert-rerank) (1.14.0)
# Requirement already satisfied: setuptools in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from torch<3.0.0,>=2.2.0->llama-index-postprocessor-colbert-rerank) (80.4.0)
# Requirement already satisfied: colorama in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from tqdm<5,>=4.66.1->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (0.4.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from transformers<5.0.0,>=4.37.2->llama-index-postprocessor-colbert-rerank) (0.31.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from transformers<5.0.0,>=4.37.2->llama-index-postprocessor-colbert-rerank) (24.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from transformers<5.0.0,>=4.37.2->llama-index-postprocessor-colbert-rerank) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from transformers<5.0.0,>=4.37.2->llama-index-postprocessor-colbert-rerank) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from transformers<5.0.0,>=4.37.2->llama-index-postprocessor-colbert-rerank) (0.5.3)
# Requirement already satisfied: idna>=2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (3.10)
# Requirement already satisfied: click in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (8.2.0)
# Requirement already satisfied: joblib in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (1.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (2025.4.26)
# Requirement already satisfied: greenlet>=1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (3.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from sympy>=1.13.3->torch<3.0.0,>=2.2.0->llama-index-postprocessor-colbert-rerank) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (3.26.1)
# Requirement already satisfied: anyio in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from jinja2->banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-postprocessor-colbert-rerank) (3.0.2)
# Using cached llama_index_postprocessor_colbert_rerank-0.3.0-py3-none-any.whl (3.5 kB)
# Installing collected packages: llama-index-postprocessor-colbert-rerank
# Successfully installed llama-index-postprocessor-colbert-rerank-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install numpy matplotlib seaborn scikit-learn
# Out:
# Requirement already satisfied: numpy in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (2.2.5)
# Requirement already satisfied: matplotlib in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (3.10.3)
# Requirement already satisfied: seaborn in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (1.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\acisse\onedrive - bridgingit-gruppe\003_codeworkspace\003_private\deeptrace\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from utils import display_citation
from llama_index.llms.openai import OpenAI

# %%
from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv("API_KEY")
assert api_key

# %%
# Load API key from environment variable
llm_openai = OpenAI(
    api_key=api_key,
    model="gpt-4o"
)

# Example usage
prompt = "Explain how RAG systems work."
display_citation(str(llm_openai.complete(prompt)))
# Out:
# > RAG systems, which stand for Retrieval-Augmented Generation systems, are a type of architecture used in natural language processing (NLP) to enhance the capabilities of language models by combining retrieval mechanisms with generative models. The primary goal of RAG systems is to improve the accuracy and relevance of generated responses by incorporating external information. Here's how they generally work:
# >
# > 1. **Retrieval Component**:
# >    - The system first uses a retrieval mechanism to search a large corpus of documents or a database to find relevant information based on the input query or context.
# >    - This retrieval process typically involves using techniques like TF-IDF, BM25, or more advanced neural retrieval models such as Dense Passage Retrieval (DPR) to identify the most pertinent documents or passages.
# >
# > 2. **Augmentation**:
# >    - The retrieved information is then used to augment the input to the generative model. This can involve concatenating the retrieved text with the original query or using it to modify the input in some other way.
# >    - The idea is to provide the generative model with additional context or facts that it might not have been able to generate on its own due to the limitations of its training data.
# >
# > 3. **Generation Component**:
# >    - A generative model, often based on architectures like GPT (Generative Pre-trained Transformer) or BART (Bidirectional and Auto-Regressive Transformers), takes the augmented input and generates a response.
# >    - The generative model uses both the original input and the retrieved information to produce a more informed and contextually relevant output.
# >
# > 4. **Integration and Output**:
# >    - The final output is a combination of the generative model's capabilities and the external knowledge provided by the retrieval component.
# >    - This approach allows the system to generate responses that are not only coherent and contextually appropriate but also factually accurate and up-to-date, as it can leverage the latest information from the retrieval corpus.
# >
# > RAG systems are particularly useful in applications where the knowledge base is too large to be fully encoded in a generative model's parameters, or where the information changes frequently, such as in customer support, question answering, and conversational agents. By integrating retrieval with generation, RAG systems can provide more accurate and reliable responses, making them a powerful tool in the field of NLP.

# %%
from llama_index.core import Settings
from llama_index.core.postprocessor import LLMRerank
from llama_index.core.query_engine import RetrieverQueryEngine

llm_openai = OpenAI(
    api_key=api_key,
    model="gpt-4o",
)

Settings.llm = llm_openai

# Configure reranker
postprocessor = LLMRerank(top_n=3, llm=llm_openai)

query_engine = RetrieverQueryEngine(
    retriever=index.as_retriever(llm=None, similarity_top_k=3),
    node_postprocessors=[postprocessor]
)
response = query_engine.query("What is m-theory")

# %%
response = query_engine.query("What is m-theory")
display_citation(response.response[:1000])
# Out:
# > M-theory is a theoretical framework in physics that aims to unify the various versions of superstring theory. It is considered a candidate for a fundamental theory of everything, combining general relativity and quantum mechanics. M-theory suggests that the fundamental building blocks of the universe are not one-dimensional strings, as in string theory, but rather two-dimensional membranes, or "branes." The theory is still not fully understood, and its complete formulation remains an open question in theoretical physics.

# %%
from llama_index.core.agent import StructuredPlannerAgent, FunctionCallingAgentWorker
from llama_index.core.tools import QueryEngineTool
from llama_index.core.tools import ToolMetadata
import nest_asyncio
nest_asyncio.apply()

# Create a query engine from our index
query_engine = index.as_query_engine()

# Wrap the query engine in a QueryEngineTool
query_engine_tool = QueryEngineTool(
    query_engine=query_engine,
    metadata=ToolMetadata(
        name="vector_index",
        description="A tool for retrieving information from a physics document index."
    )
)

# Create a function-calling worker for executing retrieval tasks
worker = FunctionCallingAgentWorker.from_tools(
    [query_engine_tool], 
    llm=llm_openai, 
    verbose=True,
    allow_parallel_tool_calls=False
)

# Initialize the structured planner agent with the worker
structured_planner = StructuredPlannerAgent(
    worker, 
    tools=[query_engine_tool], 
    verbose=True
)

# Test with a complex question
response = structured_planner.chat("How did research at Los Alamos and Bell Labs overlap?")
print(response)
# Out:
# === Initial plan ===
# Retrieve Los Alamos Research Information:
# Use the vector_index tool to retrieve information about research conducted at Los Alamos. -> A summary of research topics and projects conducted at Los Alamos.
# deps: []
#
#
# Retrieve Bell Labs Research Information:
# Use the vector_index tool to retrieve information about research conducted at Bell Labs. -> A summary of research topics and projects conducted at Bell Labs.
# deps: []
#
#
# Identify Overlapping Research Areas:
# Compare the research topics and projects from Los Alamos and Bell Labs to identify any overlaps. -> A list of overlapping research areas between Los Alamos and Bell Labs.
# deps: ['Retrieve Los Alamos Research Information', 'Retrieve Bell Labs Research Information']
#
#
# Summarize Overlapping Research:
# Summarize the overlapping research areas identified between Los Alamos and Bell Labs. -> A comprehensive summary of how research at Los Alamos and Bell Labs overlapped.
# deps: ['Identify Overlapping Research Areas']
#
#
# > Running step 920bdb2f-9228-46fa-a014-a61cff96a8ef. Step input: Use the vector_index tool to retrieve information about research conducted at Los Alamos.
# Added user message to memory: Use the vector_index tool to retrieve information about research conducted at Los Alamos.
# > Running step 12f5aaa7-611a-4082-8c39-9e00aa505f2f. Step input: Use the vector_index tool to retrieve information about research conducted at Bell Labs.
# Added user message to memory: Use the vector_index tool to retrieve information about research conducted at Bell Labs.
# === Calling Function ===
# Calling function: vector_index with args: {"input": "research conducted at Los Alamos"}
# === Calling Function ===
# Calling function: vector_index with args: {"input": "research conducted at Bell Labs"}
# === Function Output ===
# The research conducted at Los Alamos includes fundamental and applied research in partnership with universities and industry. It is one of the two American laboratories where nuclear weapons research is undertaken. The laboratory was initially founded during World War II as a central location for the scientific research of the Manhattan Project, which developed the first nuclear weapons. The team at Los Alamos consists of physicists, engineers, chemists, and experts in various other disciplines, working on a wide range of scientific projects.
# > Running step 5db9d251-0a96-4310-9236-c9ea8db87750. Step input: None
# === Function Output ===
# Bell Labs has been a hub for significant research breakthroughs in various fields such as telecommunications, mathematics, physics, materials science, and computer science. The research conducted there has led to the awarding of ten Nobel Prizes and several Turing Awards. Some notable achievements include the demonstration of electron diffraction by crystals, the discovery of radio waves from the center of our galaxy, and the development of the statistical programming language S.
# > Running step 0e265ce3-f072-43ca-b58f-76addd28a147. Step input: None
# === LLM Response ===
# Research conducted at Los Alamos encompasses both fundamental and applied research, often in collaboration with universities and industry. It is one of the two American laboratories dedicated to nuclear weapons research. Originally established during World War II for the Manhattan Project, which developed the first nuclear weapons, Los Alamos continues to be a hub for scientific research. The team includes physicists, engineers, chemists, and experts from various disciplines, working on a diverse array of scientific projects.
# === LLM Response ===
# Research conducted at Bell Labs has led to numerous groundbreaking achievements across various fields, including telecommunications, mathematics, physics, materials science, and computer science. The institution's work has been recognized with ten Nobel Prizes and several Turing Awards. Notable accomplishments include:
#
# - Demonstration of electron diffraction by crystals.
# - Discovery of radio waves emanating from the center of our galaxy.
# - Development of the statistical programming language S.
#
# These contributions highlight Bell Labs' pivotal role in advancing scientific and technological knowledge.
# === Refined plan ===
# Identify Overlapping Research Areas:
# Compare the research topics and projects from Los Alamos and Bell Labs to identify any overlaps. -> A list of overlapping research areas between Los Alamos and Bell Labs.
# deps: ['Retrieve Los Alamos Research Information', 'Retrieve Bell Labs Research Information']
#
#
# Summarize Overlapping Research:
# Summarize the overlapping research areas identified between Los Alamos and Bell Labs. -> A comprehensive summary of how research at Los Alamos and Bell Labs overlapped.
# deps: ['Identify Overlapping Research Areas']
#
#
# > Running step 27a27e69-379e-494f-aac6-cf174585911d. Step input: Compare the research topics and projects from Los Alamos and Bell Labs to identify any overlaps.
# Added user message to memory: Compare the research topics and projects from Los Alamos and Bell Labs to identify any overlaps.
# === LLM Response ===
# Both Los Alamos and Bell Labs have been instrumental in advancing scientific research, but they have traditionally focused on different areas:
#
# ### Los Alamos:
# - **Nuclear Weapons Research**: As one of the two American laboratories dedicated to this field, Los Alamos has a strong focus on nuclear weapons research.
# - **Manhattan Project**: Historically, it was the central location for the development of the first nuclear weapons during World War II.
# - **Multidisciplinary Scientific Projects**: Involves physicists, engineers, chemists, and other experts working on a wide range of scientific projects.
#
# ### Bell Labs:
# - **Telecommunications**: Known for significant breakthroughs in telecommunications technology.
# - **Mathematics and Computer Science**: Contributions include the development of the statistical programming language S and other computational advancements.
# - **Physics and Materials Science**: Achievements include the demonstration of electron diffraction by crystals and the discovery of radio waves from the center of our galaxy.
#
# ### Overlaps:
# - **Physics**: Both institutions have made significant contributions to the field of physics. Los Alamos with its nuclear research and Bell Labs with its work on electron diffraction and radio waves.
# - **Multidisciplinary Approach**: Both labs employ a multidisciplinary approach, involving experts from various fields to tackle complex scientific challenges.
#
# While there are overlaps in the broad field of physics and the multidisciplinary nature of their research, the specific focus areas and historical contexts of their projects differ significantly. Los Alamos is more focused on nuclear research, whereas Bell Labs has a broader focus on telecommunications and computational sciences.
# === Refined plan ===
# Summarize Overlapping Research:
# Summarize the overlapping research areas identified between Los Alamos and Bell Labs. -> A comprehensive summary of how research at Los Alamos and Bell Labs overlapped.
# deps: ['Identify Overlapping Research Areas']
#
#
# > Running step 2e02d316-fc1f-44a0-bb50-96df811533d3. Step input: Summarize the overlapping research areas identified between Los Alamos and Bell Labs.
# Added user message to memory: Summarize the overlapping research areas identified between Los Alamos and Bell Labs.
# === LLM Response ===
# The overlapping research areas between Los Alamos and Bell Labs primarily lie in the field of physics and their multidisciplinary approach to scientific research:
#
# 1. **Physics**: Both institutions have made significant contributions to physics. Los Alamos is known for its nuclear research, while Bell Labs has contributed to electron diffraction and the discovery of radio waves.
#
# 2. **Multidisciplinary Approach**: Both labs employ a multidisciplinary approach, involving experts from various fields to address complex scientific challenges.
#
# These overlaps highlight their shared commitment to advancing scientific knowledge through diverse and collaborative research efforts.
# === Refined plan ===
# Retrieve Los Alamos Research Information:
# Research conducted at Los Alamos -> Information about Los Alamos research areas and achievements.
# deps: []
#
#
# Retrieve Bell Labs Research Information:
# Research conducted at Bell Labs -> Information about Bell Labs research areas and achievements.
# deps: []
#
#
# Identify Overlapping Research Areas:
# Compare research areas and achievements of Los Alamos and Bell Labs -> Identify overlapping research areas between Los Alamos and Bell Labs.
# deps: ['Retrieve Los Alamos Research Information', 'Retrieve Bell Labs Research Information']
#
#
# Summarize Overlapping Research:
# Summarize the overlapping research areas identified between Los Alamos and Bell Labs -> A summary of the overlapping research areas between Los Alamos and Bell Labs.
# deps: ['Identify Overlapping Research Areas']
#
#
# The overlapping research areas between Los Alamos and Bell Labs primarily lie in the field of physics and their multidisciplinary approach to scientific research:
#
# 1. **Physics**: Both institutions have made significant contributions to physics. Los Alamos is known for its nuclear research, while Bell Labs has contributed to electron diffraction and the discovery of radio waves.
#
# 2. **Multidisciplinary Approach**: Both labs employ a multidisciplinary approach, involving experts from various fields to address complex scientific challenges.
#
# These overlaps highlight their shared commitment to advancing scientific knowledge through diverse and collaborative research efforts.
